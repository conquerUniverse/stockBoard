# %% [markdown]
# # **StockBoard**
# - [ ] Link Dash with colab
# - [ ] Make simple UI and test it
# - [ ] Upload your trading Data
# - [ ] Add visualizations and charts

# %%
# !pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Downloading pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 43 kB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /home/alvin/anaconda3/lib/python3.6/site-packages (from pandas-datareader) (0.23.0)
# Requirement already satisfied: lxml in /home/alvin/anaconda3/lib/python3.6/site-packages (from pandas-datareader) (4.2.1)
# Collecting requests>=2.19.0
#   Downloading requests-2.24.0-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 61 kB/s  eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/alvin/anaconda3/lib/python3.6/site-packages (from pandas>=0.23->pandas-datareader) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/alvin/anaconda3/lib/python3.6/site-packages (from pandas>=0.23->pandas-datareader) (2018.4)
# Requirement already satisfied: numpy>=1.9.0 in /home/alvin/anaconda3/lib/python3.6/site-packages (from pandas>=0.23->pandas-datareader) (1.14.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/alvin/anaconda3/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alvin/anaconda3/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader) (2018.4.16)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/alvin/anaconda3/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/alvin/anaconda3/lib/python3.6/site-packages (from requests>=2.19.0->pandas-datareader) (1.22)
# Requirement already satisfied: six>=1.5 in /home/alvin/anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas>=0.23->pandas-datareader) (1.11.0)
# Installing collected packages: requests, pandas-datareader
#   Attempting uninstall: requests
#     Found existing installation: requests 2.18.4
#     Uninstalling requests-2.18.4:
#       Successfully uninstalled requests-2.18.4
# Successfully installed pandas-datareader-0.9.0 requests-2.24.0

# %%
# use alpha vantage api for real time stock data
# !pip install alpha_vantage
from pandas_datareader import data

# %%
tickers = ['AAPL', 'MSFT', '^GSPC']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2010-01-01'
end_date = '2016-12-31'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader('INPX', 'google', start_date, end_date)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-7-bae868c98717> in <module>()
#       6
#       7 # User pandas_reader.data.DataReader to load the desired data. As simple as that.
# ----> 8 panel_data = data.DataReader('INPX', 'google', start_date, end_date)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     371     if data_source not in expected_source:
#     372         msg = "data_source=%r is not implemented" % data_source
# --> 373         raise NotImplementedError(msg)
#     374
#     375     if data_source == "yahoo":
#
# NotImplementedError: data_source='google' is not implemented

# %% [markdown]
# # Import Libraries

# %%
import StockData as sd 
import StockBoard as sb

# %%
a = sd.StockData()
a.load()
stock = sb.StockBoard(a)
# Out:
# Files Successfully loaded

# %% [markdown]
# ## Get your current balance

# %%
stock.getCurrBalance()
# Out:
# 367.1

# %%
a.getData('SEll')
# Out:
#        Name  NumberOfStocks  SellingPrice        Date  TotalCost  \
# 0      SBIN              10         196.5  2020-03-26    1965.00
# 1      INFY               3         932.0  2020-07-16    2792.89
# 2  SBICARDS              19         796.0  2020-07-21   15108.15
# 3     IOLCP              28         796.0  2020-07-29   22312.49
#
#    ExtraCharges  BrokerageCost
# 0         27.43          27.43
# 1          0.00           3.11
# 2          0.00          15.85
# 3          0.00          24.49

# %%
import os
import pandas as pd

# %%
os.environ['ALPHAVANTAGE_API_KEY'] = "D1RTSKPBB3ZBWOWO" 
apiKey = os.getenv('ALPHAVANTAGE_API_KEY')
print(apiKey)
# Out:
# D1RTSKPBB3ZBWOWO

# %% [markdown]
# ## AlphaVantage APIs

# %%
from alpha_vantage.timeseries import TimeSeries 
# from alpha_vantage.alphavantage import 

app = TimeSeries(output_format='pandas')
# app.get_intraday('GOOGL') 
# app.get_daily_adjusted('BSE:INFY', outputsize='compact')

# %%
d = app.get_intraday('GOOGL')

# %%
d[0].columns = ['open','high','low','close','volume']

# %%
d[0]['close'].plot()

# %%
aapl = app.get_daily_adjusted('BSE:INFY', outputsize='compact')
# print(appl)

# %%
aapl[0]
# Out:
#             1. open  2. high   3. low  4. close  5. adjusted close  \
# date
